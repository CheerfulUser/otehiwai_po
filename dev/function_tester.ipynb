# %%
import sys
sys.path.append('../otehiwai_po/')
from scheduler import make_schedule

# %%
make_schedule()
# Out:
# /Users/rri38/Documents/work/code/otehiwai_po/otehiwai_po/20221112
# ['/Users/rri38/Documents/work/code/otehiwai_po/otehiwai_po/targets/20221112/look.json']
# !!!!  /Users/rri38/Documents/work/code/otehiwai_po/otehiwai_po/targets/20221112/look.json

# %%
from glob import glob

# %%
targets = glob('/Users/rri38/Documents/work/code/otehiwai_po/otehiwai_po/20221112' + '/*' )

# %%
targets
# Out:
# []
